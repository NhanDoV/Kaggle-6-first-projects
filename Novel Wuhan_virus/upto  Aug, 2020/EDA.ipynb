# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Overview

# %%
pwd = os.getcwd()
df_country_wise_latest = pd.read_csv(f"{pwd}/datasets_until_Aug_country_wise_latest.csv")
df_worldometer = pd.read_csv(f"{pwd}/datasets_until_Aug_worldometer_data.csv")

print("datasets_until_Aug_country_wise_latest.csv")
display(df_country_wise_latest.head())
print("datasets_until_Aug_worldometer_data.csv")
display(df_worldometer.head())
# Out:
# datasets_until_Aug_country_wise_latest.csv
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# ## 1. datasets_until_Aug_country_wise_latest

# %%
import visualize as vl
import warnings

warnings.filterwarnings("ignore")

targ_col = 'Country/Region'
col = 'Confirmed'
inp_dt = df_country_wise_latest.fillna(0)

for col in df_country_wise_latest.columns[1:-1]:
    vl.top_show(inp_dt, col, targ_col)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
